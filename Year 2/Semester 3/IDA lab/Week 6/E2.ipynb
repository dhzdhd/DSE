# %% [markdown]
# ## Week 6
# ## Exercise 2: Text Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv("amazon_baby.csv")

# %%
df
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [183531 rows x 3 columns]

# %% [markdown]
# ### Q1) Check the number of the reviews received for each product.

# %%
df.groupby("name")[["review"]].count()
# Out:
#                                                     review
# name
# # 1 Digital Baby Thermometer - With FREE LIFETI...       4
# #1 Adjustable Back Seat Baby Safety Mirror - Ea...       1
# #1 Baby Bottle Brush for All Types of Bottles &...       3
# #1 Premium Baby Nasal Aspirator by Cutietots - ...       4
# #120 - 2.5mm Dr Mom Specula Tips - Premium Quality       2
# ...                                                    ...
# zCush Cotton Characters Nap Mat, Googly Green            1
# zTcase&trade; Bluetooth Wireless Keyboard Case ...       1
# zutano for aden by aden + anais 100% Cotton Mus...       2
# zutano for aden by aden + anais 100% Cotton Mus...       2
# zutano for aden by aden + anais 100% Cotton Mus...       3
#
# [32417 rows x 1 columns]

# %% [markdown]
# ### Q2) Check the products that have more than 15 reviews.

# %%
temp = pd.DataFrame(df.groupby("name")[["review"]].count())
temp.loc[temp["review"] > 15]
# Out:
#                                                     review
# name
# &quot;A Little Pillow Company&quot; Hypoallerge...      32
# (1) Cresci Products Window Wedge (2 Per Pack) W...      25
# *SPECIAL PROMOTION*The Art of CureTM *SAFETY KN...      62
# *The Art of CureTM *SAFETY KNOTTED* - Mixed Col...      24
# *The Art of CureTM *SAFETY KNOTTED* Lemon - Cer...      21
# ...                                                    ...
# myBaby Soundspa Lullaby Sound Machine and Proje...      87
# mybaby HoMedics SoundSpa On-The-Go                      57
# phil&amp;teds Lobster Highchair, Red                    31
# phil&amp;teds Traveller Crib, Black                     21
# timi &amp; leslie Charlie 7-Piece Diaper Bag Se...      26
#
# [2327 rows x 1 columns]

# %% [markdown]
# ### Q3) Find any missing review are present or not, if present remove those data.

# %%
df.dropna(how="any", subset=["review"], inplace=True)
df
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [182702 rows x 3 columns]

# %% [markdown]
# ### Q4) Clean the data and remove the special characters and replace the contractions with its expansion by converting the uppercase character to lower case. Also, remove the punctuations

# %%
contractions = {
    "a'ight":"alright",
    "ain't":"are not",
    "amn't":"am not",
    "aren't":"are not",
    "can't":"cannot",
    "'cause": "because",
    "could've":"could have",
    "couldn't":"could not",
    "couldn't've":"could not have",
    "daren't":"dare not",
    "daresn't":"dare not",
    "dasn't":"dare not",
    "didn't":"did not",
    "doesn't":"does not",
    "don't":"do not",
    "everybody's":"everybody is",
    "everyone's":"everyone is",
    "giv'n":"given",
    "gonna":"going to",
    "gon't":"go not", 
    "gotta":"got to",
    "hadn't":"had not",
    "had've":"had have",
    "hasn't":"has not",
    "haven't":"have not",
    "he'd":"he had", 
    "he'll":"he will",
    "he's":"he is",
    "here's":"here is",
    "how'd":"how did",
    "how'll":"how will",
    "how're":"how are",
    "how's":"how is",
    "I'd":"I had",
    "I'd've":"I would have",
    "I'd'nt":"I would not",
    "I'd'nt've":"I would not have",
    "I'll":"I will",
    "I'm":"I am",
    "I've":"I have",
    "isn't":"is not",
    "it'd":"it would",
    "it'll":"it will",
    "it's":"it is",
    "let's":"let us",
    "ma'am":"madam",
    "mayn't":"may not",
    "may've":"may have",
    "mightn't":"might not",
    "might've":"might have",
    "mustn't":"must not",
    "mustn't've":"must not have",
    "must've":"must have",
    "needn't":"need not",
    "needn't've":"need not have",
    "o'clock":"of the clock",
    "oughtn't":"ought not",
    "oughtn't've":"ought not have",
    "shan't":"shall not",
    "she'd":"she would",
    "she'll":"she will",
    "she's":"she is",
    "should've":"should have",
    "shouldn't":"should not",
    "shouldn't've":"should not have",
    "somebody's":"somebody is",
    "someone's":"someone is",
    "something's":"something is",
    "so're":"so are",
    "so’s":"so is",
    "so’ve":"so have",
    "that'll":"that will",
    "that're":"that are",
    "that's":"that is",
    "that'd":"that would",
    "there'd":"there would",
    "there'll":"there will",
    "there're":"there are",
    "there's":"there is",
    "these're":"these are",
    "these've":"these have",
    "they'd":"they would",
    "they'll":"they will",
    "they're":"they are",
    "they've":"they have",
    "this's":"this is",
    "those're":"those are",
    "those've":"those have",
    "to've":"to have",
    "wasn't":"was not",
    "we'd":"we would",
    "we'd've":"we would have",
    "we'll":"we will",
    "we're":"we are",
    "we've":"we have",
    "weren't":"were not",
    "what'd":"what did",
    "what'll":"what will",
    "what're":"what are",
    "what's":"what is",
    "what've":"what have",
    "when's":"when is",
    "where'd":"where did",
    "where'll":"where will",
    "where're":"where are",
    "where's":"where is",
    "where've":"where have",
    "which'd":"which would",
    "which'll":"which will",
    "which're":"which are",
    "which's":"which is",
    "which've":"which have",
    "who'd":"who would",
    "who'd've":"who would have",
    "who'll":"who will",
    "who're":"who are",
    "who's":"who is",
    "who've":"who have",
    "why'd":"why did",
    "why're":"why are",
    "why's":"why is",
    "won't":"will not",
    "would've":"would have",
    "wouldn't":"would not",
    "wouldn't've":"would not have",
    "y'at":"you at",
    "yes’m":"yes madam",
    "you'd":"you would",
    "you'll":"you will",
    "you're":"you are",
    "you've":"you have"
}

# %%
def cont_to_exp(x):
    if type(x) is str:
        x = x.replace('\\','')
        for key in contractions:
            value = contractions[key]
            x = x.replace(key, value)
    return x
    
df['review'] = df['review'].apply(lambda x:cont_to_exp(x))
df
# Out:
#                                                      name  \
# 0                                planetwise flannel wipes
# 1                                   planetwise wipe pouch
# 2                     annas dream full quilt with 2 shams
# 3       stop pacifier sucking without tears with thumb...
# 4       stop pacifier sucking without tears with thumb...
# ...                                                   ...
# 183526  baby teething necklace for mom pretty donut sh...
# 183527  baby teething necklace for mom pretty donut sh...
# 183528      abstract 2 pk baby  toddler training cup pink
# 183529  baby food freezer tray  bacteria resistant bpa...
# 183530  best 2 pack baby car shade for kids  window sh...
#
#                                                    review  rating  word count  \
# 0       these flannel wipes are ok, but in my opinion ...       3          79
# 1       it came early and was not disappointed. i love...       5          30
# 2       very soft and comfortable and warmer than it l...       5          23
# 3       this is a product well worth the purchase.  i ...       5          74
# 4       all of my kids have cried non-stop when i trie...       5          76
# ...                                                   ...     ...         ...
# 183526  such a great idea! very handy to have and look...       5          27
# 183527  this product rocks!  it is a great blend of fu...       5          64
# 183528  this item looks great and cool for my kids.......       5          17
# 183529  i am extremely happy with this product. i have...       5         170
# 183530  i love this product very mush . i have bought ...       5          38
#
#         length of review
# 0                    452
# 1                    158
# 2                    143
# 3                    390
# 4                    405
# ...                  ...
# 183526               138
# 183527               354
# 183528                93
# 183529               854
# 183530               196
#
# [182702 rows x 5 columns]

# %% [markdown]
# ### Q5) Add the Polarity, length of the review, the word count and average word length of each review.

# %%
from textblob import TextBlob

df['polarity'] = df['review'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['review_len'] = df['review'].apply(lambda x:len(x))
df['word_count'] = df['review'].apply(lambda x: len(x.split()))


def get_avg_word_len(x):
    words = x.split()
    word_len = 0
    for word in words:
        word_len = word_len + len(word)
        
    return word_len/len(words) 


df['avg_word_len'] = df['review'].apply(lambda x: get_avg_word_len(x))

# %% [markdown]
# ### Q6) Visualize the distribution of the word count, review length, and polarity.

# %%
df['polarity'].hist(bins=20)
plt.xlabel('polarity')
plt.ylabel('count')
plt.title('Sentiment Polarity Distribution')

# %%
# Histogram for review length
df['review_len'].hist(bins=20)
plt.xlabel('review length')
plt.ylabel('count')
plt.title('Review Text Length Distribution')

# %%
# Histogram for word count
df['word_count'].hist(bins=20)
plt.xlabel('word count')
plt.ylabel('count')
plt.title('Word Count Distribution')

# %% [markdown]
# ### Q7) Visualize polarity considering the rating.

# %%
df.groupby(by='rating').polarity.agg([np.mean]).plot()
plt.xlabel('rating')
plt.ylabel('polarity')
plt.title('Polarity considering Rating')

# %% [markdown]
# ### Q8) Visualize the count of the reviews of each rating available in the dataset

# %%
df.groupby(by='rating').review.count().plot.bar()
plt.xlabel('rating')
plt.ylabel('no. of reviews')
plt.title('count of the reviews of each rating')

# %% [markdown]
# ### Q9) List the Top 20 products based on the polarity.

# %%
df.sort_values(by='polarity', ascending=False)[0:20]

# %% [markdown]
# ### Q10) Visualize to check whether the review length changes with rating

# %%
sns.barplot(x='rating', y='review_len', data=df, ci=None)
plt.xlabel('rating')
plt.ylabel('review length')
plt.title('Review Length vs Rating')

# %% [markdown]
# ### Q11) Visualize the distribution of Top 25 Unigram, Bigram and Trigram

# %%
def get_top_n_words(x, n=25):
    vec = CountVectorizer(stop_words='english').fit(x)
    bag_of_words = vec.transform(x)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
common_words = get_top_n_words(df['review'], 25)
common_words
df1 = pd.DataFrame(common_words, columns = ['Unigram Text' , 'Count'])

df1.set_index('Unigram Text', drop=True, inplace=True)
df1.plot.bar()
plt.xlabel('unigrams')
plt.ylabel('count')
plt.title('Unigrams Count')

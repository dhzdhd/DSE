# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("mtcars.csv")
df
# Out:
#                   Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
# Metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# ## Q1) Tabulate number of cylinders in dataset

# %%
df[["cyl"]].value_counts()
# Out:
# cyl
# 8      14
# 4      11
# 6       7
# dtype: int64

# %% [markdown]
# ## Q2) Find five number summary of mpg

# %%
df["mpg"].describe()
# Out:
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64

# %% [markdown]
# ## Q3) Draw histogram for hp

# %%
sns.histplot(df[["hp"]])
plt.xlabel("Frequency")
plt.ylabel("HP")
plt.show()

# %% [markdown]
# ## Q4) Box plot of mpg

# %%
sns.boxplot(df[["mpg"]])
plt.title("Boxplot of MPG")
plt.ylabel("MPG")
plt.show()
# Out:
# c:\Users\ragas\.pyenv\pyenv-win\versions\3.10.7\lib\site-packages\seaborn\categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %% [markdown]
# ## Q5) Find the avg weight of all cars

# %%
df["wt"].mean()
# Out:
# 3.2172500000000004

# %% [markdown]
# ## Q6) Find the car with the minimum displacement

# %%
df.loc[df["disp"].idxmin(), "Model"]
# Out:
# 'Toyota Corolla'

# %% [markdown]
# ## Q7) Find the car with the maximum qsec

# %%
df.loc[df["qsec"].idxmax(), "Model"]
# Out:
# 'Merc 230'

# %% [markdown]
# ## Q8) Find the median horse power and find the car with the highest fuel efficiency

# %%
df["hp"].median()
# Out:
# 123.0

# %%
# Highest fuel efficiency
df.loc[df["mpg"].idxmax(), "Model"]
# Out:
# 'Toyota Corolla'

# %% [markdown]
# ## Q9) Find the car with the lowest fuel efficiency

# %%
df.loc[df["mpg"].idxmin(), "Model"]
# Out:
# 'Cadillac Fleetwood'

# %% [markdown]
# ## Q10) Find the car with the best hp

# %%
df.loc[df["hp"].idxmax(), "Model"]
# Out:
# 'Maserati Bora'

# %% [markdown]
# ## Q11) Tabulate mpg for different number of gears

# %%
pd.crosstab(df.mpg, df.gear)
# Out:
# gear  3  4  5
# mpg
# 10.4  2  0  0
# 13.3  1  0  0
# 14.3  1  0  0
# 14.7  1  0  0
# 15.0  0  0  1
# 15.2  2  0  0
# 15.5  1  0  0
# 15.8  0  0  1
# 16.4  1  0  0
# 17.3  1  0  0
# 17.8  0  1  0
# 18.1  1  0  0
# 18.7  1  0  0
# 19.2  1  1  0
# 19.7  0  0  1
# 21.0  0  2  0
# 21.4  1  1  0
# 21.5  1  0  0
# 22.8  0  2  0
# 24.4  0  1  0
# 26.0  0  0  1
# 27.3  0  1  0
# 30.4  0  1  1
# 32.4  0  1  0
# 33.9  0  1  0

# %% [markdown]
# ## Q12) Do side by side boxplot of mpg for cars with am vs manual transmission

# %%
sns.boxplot(y='mpg',x='am',data=df)
plt.title('Boxplot')
plt.show()

# %%
import numpy as np
import random
import time
import cv2
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import tensorflow.keras.backend as K
from tensorflow.keras import Sequential
from tensorflow.keras import Model, callbacks
from tensorflow.keras.layers import Dense, Flatten, Reshape, UpSampling2D,BatchNormalization, Dropout, Conv2D, Conv2DTranspose
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

#import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# load data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
# Enter BUFFER_SIZE so that the sample size is a multiple of BATCH_SIZE
BUFFER_SIZE = x_train.shape[0]
BATCH_SIZE = 100

BUFFER_SIZE = BUFFER_SIZE // BATCH_SIZE * BATCH_SIZE
x_train = x_train[:BUFFER_SIZE]
y_train = y_train[:BUFFER_SIZE]
print(f'Input data shape: {x_train.shape}')
print(f'Number of labels: {y_train.size}')
# Out:
# Input data shape: (60000, 28, 28)
# Number of labels: 60000

# %%
# Data normalization
x_train = x_train / 255
x_test = x_test / 255

# We form tensors for training and test samples
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# Splitting the training sample into BATCHES
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
cnt_imgs = 32
counter = 0
IMAGE_SIZE = (64, 64)
plt.figure(figsize=(28, 10))
for img in x_train:
    plt.subplot(4, 8, counter + 1)
    draw_img = cv2.resize(img, IMAGE_SIZE)
    plt.imshow(draw_img, cmap='gray')
    plt.axis('off')
    counter += 1
    if counter == cnt_imgs:
        break

# %%
# loss function
cross_entropy = BinaryCrossentropy(from_logits=True)

def generator_loss(fake_output):
    """Function of finding the value of the loss function for the generator (for BATCH)"""
    loss = cross_entropy(tf.ones_like(fake_output), fake_output)
    return loss


def discriminator_loss(real_output, fake_output):
    """Function of finding the value of the loss function for the discriminator (for BATCH)"""
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %%
generator_optimizer = tf.optimizers.Adam(1e-4)
discriminator_optimizer = tf.optimizers.Adam(1e-4)

# %%
# We will feed a vector of independent random variables of the hidden dim dimension to the input of the generator
hidden_dim = 100

# %%
# First, let's create a generator model
generator = Sequential(name='generator')
generator.add(Dense(7 * 7 * 256, activation='relu', input_shape=(hidden_dim, )))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 256)))  # got a tensor
generator.add(Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', activation='relu'))
generator.add(BatchNormalization())
generator.add(Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', activation='relu'))
generator.add(BatchNormalization())
generator.add(Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', activation='sigmoid'))

# %%
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12544)             37632
#
#  batch_normalization (Batch  (None, 12544)             50176
#  Normalization)
#
#  reshape (Reshape)           (None, 7, 7, 256)         0
#
#  conv2d_transpose (Conv2DTr  (None, 7, 7, 128)         819328
#  anspose)
#
#  batch_normalization_1 (Bat  (None, 7, 7, 128)         512
#  chNormalization)
#
#  conv2d_transpose_1 (Conv2D  (None, 14, 14, 64)        204864
#  Transpose)
#
#  batch_normalization_2 (Bat  (None, 14, 14, 64)        256
#  chNormalization)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         1601
#  Transpose)
#
# =================================================================
# Total params: 1114369 (4.25 MB)
# Trainable params: 1088897 (4.15 MB)
# Non-trainable params: 25472 (99.50 KB)
# _________________________________________________________________

# %%
discriminator = Sequential(name='discriminator')
discriminator.add(Conv2D(64, (5, 5), strides=(2, 2), padding='same', activation='elu', input_shape=(28, 28, 1)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, (5, 5), strides=(2, 2), padding='same', activation='elu'))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(64, activation='relu'))
discriminator.add(Dense(1, activation='sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 discriminator = Sequential(name='discriminator')
#       2 discriminator.add(Conv2D(64, (5, 5), strides=(2, 2), padding='same', activation='elu', input_shape=(28, 28, 1)))
#       3 discriminator.add(Dropout(0.3))
#
# NameError: name 'Sequential' is not defined

# %%
# compiling neural networks
generator.compile(optimizer=generator_optimizer, loss='binary_crossentropy')
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')

# %%
# Generator and Discriminator training
@tf.function
def train_step(images) -> (float, float):
    """Function for updating weight coefficients at one training step (for one BATCH)"""
    noise = tf.random.normal([BATCH_SIZE, hidden_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)

        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

        generator_gradients = gen_tape.gradient(gen_loss, generator.trainable_variables)
        discriminator_gradients = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

        generator_optimizer.apply_gradients(zip(generator_gradients, generator.trainable_variables))
        discriminator_optimizer.apply_gradients(zip(discriminator_gradients, discriminator.trainable_variables))
        return gen_loss, disc_loss

# %%
# the learning process for all epochs
def train(dataset,  epochs) -> None:
    """A function to start the learning process for all epochs for the generator and discriminator
    dataset: a set of real images that we store in  generator"""
    history = []
    max_print_label = 10
    th = BUFFER_SIZE // (BATCH_SIZE * max_print_label)

    for epoch in range(1, EPOCHS + 1):
        print(f'{epoch}/{EPOCHS}: ', end='')
        start = time.time()
        n = 0
        gen_loss_epoch = 0
        for image_batch in dataset:
            gen_loss, disc_loss = train_step(image_batch)
            gen_loss_epoch += K.mean(gen_loss)
            if (n % th == 0):
                print('=', end='')
            n += 1
        print('>', end = ' ')

        history += [gen_loss_epoch / n]
        print(': loss = ' + str(history[-1]))
        print(f'The time of the epoch {epoch} is: {time.time() - start} second')
    return history

# %%
# # Starting the learning process
EPOCHS = 100
gen_history = train(train_dataset, EPOCHS)
# Out:
# 1/100: ==========> : loss = tf.Tensor(4.5346527, shape=(), dtype=float32)
# The time of the epoch 1 is: 28.572259664535522 second
# 2/100: ==========> : loss = tf.Tensor(2.1735723, shape=(), dtype=float32)
# The time of the epoch 2 is: 10.673367023468018 second
# 3/100: ==========> : loss = tf.Tensor(2.2355218, shape=(), dtype=float32)
# The time of the epoch 3 is: 10.517440557479858 second
# 4/100: ==========> : loss = tf.Tensor(1.9126794, shape=(), dtype=float32)
# The time of the epoch 4 is: 10.57545804977417 second
# 5/100: ==========> : loss = tf.Tensor(1.6883981, shape=(), dtype=float32)
# The time of the epoch 5 is: 10.668347358703613 second
# 6/100: ==========> : loss = tf.Tensor(1.741864, shape=(), dtype=float32)
# The time of the epoch 6 is: 10.752326250076294 second
# 7/100: ==========> : loss = tf.Tensor(1.8908305, shape=(), dtype=float32)
# The time of the epoch 7 is: 20.464927434921265 second
# 8/100: ==========> : loss = tf.Tensor(1.8593856, shape=(), dtype=float32)
# The time of the epoch 8 is: 10.834286212921143 second
# 9/100: ==========> : loss = tf.Tensor(1.8076564, shape=(), dtype=float32)
# The time of the epoch 9 is: 10.825138330459595 second
# 10/100: ==========> : loss = tf.Tensor(2.0004802, shape=(), dtype=float32)
# The time of the epoch 10 is: 10.95967721939087 second
# 11/100: ==========> : loss = tf.Tensor(1.8044275, shape=(), dtype=float32)
# The time of the epoch 11 is: 10.978904008865356 second
# 12/100: ==========> : loss = tf.Tensor(1.7264718, shape=(), dtype=float32)
# The time of the epoch 12 is: 10.884122848510742 second
# 13/100: ==========> : loss = tf.Tensor(1.7495089, shape=(), dtype=float32)
# The time of the epoch 13 is: 10.843076705932617 second
# 14/100: ==========> : loss = tf.Tensor(1.8102129, shape=(), dtype=float32)
# The time of the epoch 14 is: 10.881013870239258 second
# 15/100: ==========> : loss = tf.Tensor(1.6223141, shape=(), dtype=float32)
# The time of the epoch 15 is: 10.78187370300293 second
# 16/100: ==========> : loss = tf.Tensor(1.6630304, shape=(), dtype=float32)
# The time of the epoch 16 is: 10.824973344802856 second
# 17/100: ==========> : loss = tf.Tensor(1.5623848, shape=(), dtype=float32)
# The time of the epoch 17 is: 10.861849784851074 second
# 18/100: ==========> : loss = tf.Tensor(1.3358568, shape=(), dtype=float32)
# The time of the epoch 18 is: 10.838599443435669 second
# 19/100: ==========> : loss = tf.Tensor(1.4567038, shape=(), dtype=float32)
# The time of the epoch 19 is: 10.84776782989502 second
# 20/100: ==========> : loss = tf.Tensor(1.454678, shape=(), dtype=float32)
# The time of the epoch 20 is: 10.843117475509644 second
# 21/100: ==========> : loss = tf.Tensor(1.5344477, shape=(), dtype=float32)
# The time of the epoch 21 is: 10.840016603469849 second
# 22/100: ==========> : loss = tf.Tensor(1.6557622, shape=(), dtype=float32)
# The time of the epoch 22 is: 10.826596021652222 second
# 23/100: ==========> : loss = tf.Tensor(1.4681188, shape=(), dtype=float32)
# The time of the epoch 23 is: 10.860398054122925 second
# 24/100: ==========> : loss = tf.Tensor(1.4001634, shape=(), dtype=float32)
# The time of the epoch 24 is: 10.832676649093628 second
# 25/100: ==========> : loss = tf.Tensor(1.3517573, shape=(), dtype=float32)
# The time of the epoch 25 is: 20.46967339515686 second
# 26/100: ==========> : loss = tf.Tensor(1.3490103, shape=(), dtype=float32)
# The time of the epoch 26 is: 10.861441850662231 second
# 27/100: ==========> : loss = tf.Tensor(1.4440222, shape=(), dtype=float32)
# The time of the epoch 27 is: 10.896470546722412 second
# 28/100: ==========> : loss = tf.Tensor(1.5862892, shape=(), dtype=float32)
# The time of the epoch 28 is: 10.9643874168396 second
# 29/100: ==========> : loss = tf.Tensor(1.3921707, shape=(), dtype=float32)
# The time of the epoch 29 is: 10.911951065063477 second
# 30/100: ==========> : loss = tf.Tensor(1.4107324, shape=(), dtype=float32)
# The time of the epoch 30 is: 10.842468738555908 second
# 31/100: ==========> : loss = tf.Tensor(1.3894233, shape=(), dtype=float32)
# The time of the epoch 31 is: 10.778360605239868 second
# 32/100: ==========> : loss = tf.Tensor(1.4697388, shape=(), dtype=float32)
# The time of the epoch 32 is: 20.463781356811523 second
# 33/100: ==========> : loss = tf.Tensor(1.3306733, shape=(), dtype=float32)
# The time of the epoch 33 is: 10.777592182159424 second
# 34/100: ==========> : loss = tf.Tensor(1.3055555, shape=(), dtype=float32)
# The time of the epoch 34 is: 10.816893339157104 second
# 35/100: ==========> : loss = tf.Tensor(1.2706028, shape=(), dtype=float32)
# The time of the epoch 35 is: 10.945164442062378 second
# 36/100: ==========> : loss = tf.Tensor(1.2077668, shape=(), dtype=float32)
# The time of the epoch 36 is: 10.97418212890625 second
# 37/100: ==========> : loss = tf.Tensor(1.255714, shape=(), dtype=float32)
# The time of the epoch 37 is: 10.861371517181396 second
# 38/100: ==========> : loss = tf.Tensor(1.3902442, shape=(), dtype=float32)
# The time of the epoch 38 is: 10.801813125610352 second
# 39/100: ==========> : loss = tf.Tensor(1.3725717, shape=(), dtype=float32)
# The time of the epoch 39 is: 10.7523353099823 second
# 40/100: ==========> : loss = tf.Tensor(1.2232655, shape=(), dtype=float32)
# The time of the epoch 40 is: 10.738071918487549 second
# 41/100: ==========> : loss = tf.Tensor(1.3066001, shape=(), dtype=float32)
# The time of the epoch 41 is: 10.803577184677124 second
# 42/100: ==========> : loss = tf.Tensor(1.3281385, shape=(), dtype=float32)
# The time of the epoch 42 is: 10.7885000705719 second
# 43/100: ==========> : loss = tf.Tensor(1.3180275, shape=(), dtype=float32)
# The time of the epoch 43 is: 10.803755521774292 second
# 44/100: ==========> : loss = tf.Tensor(1.3178861, shape=(), dtype=float32)
# The time of the epoch 44 is: 10.805720567703247 second
# 45/100: ==========> : loss = tf.Tensor(1.2671891, shape=(), dtype=float32)
# The time of the epoch 45 is: 10.804801940917969 second
# 46/100: ==========> : loss = tf.Tensor(1.2106639, shape=(), dtype=float32)
# The time of the epoch 46 is: 10.805426836013794 second
# 47/100: ==========> : loss = tf.Tensor(1.2300651, shape=(), dtype=float32)
# The time of the epoch 47 is: 10.806967496871948 second
# 48/100: ==========> : loss = tf.Tensor(1.2157058, shape=(), dtype=float32)
# The time of the epoch 48 is: 10.784133672714233 second
# 49/100: ==========> : loss = tf.Tensor(1.1668522, shape=(), dtype=float32)
# The time of the epoch 49 is: 20.463648557662964 second
# 50/100: ==========> : loss = tf.Tensor(1.1995046, shape=(), dtype=float32)
# The time of the epoch 50 is: 10.788586616516113 second
# 51/100: ==========> : loss = tf.Tensor(1.1698024, shape=(), dtype=float32)
# The time of the epoch 51 is: 10.826257467269897 second
# 52/100: ==========> : loss = tf.Tensor(1.2018987, shape=(), dtype=float32)
# The time of the epoch 52 is: 10.929596662521362 second
# 53/100: ==========> : loss = tf.Tensor(1.1864163, shape=(), dtype=float32)
# The time of the epoch 53 is: 10.883032083511353 second
# 54/100: ==========> : loss = tf.Tensor(1.1185079, shape=(), dtype=float32)
# The time of the epoch 54 is: 10.817708253860474 second
# 55/100: ==========> : loss = tf.Tensor(1.3210055, shape=(), dtype=float32)
# The time of the epoch 55 is: 10.767411231994629 second
# 56/100: ==========> : loss = tf.Tensor(1.3073455, shape=(), dtype=float32)
# The time of the epoch 56 is: 10.721840858459473 second
# 57/100: ==========> : loss = tf.Tensor(1.235513, shape=(), dtype=float32)
# The time of the epoch 57 is: 10.751880645751953 second
# 58/100: ==========> : loss = tf.Tensor(1.1777202, shape=(), dtype=float32)
# The time of the epoch 58 is: 10.775760650634766 second
# 59/100: ==========> : loss = tf.Tensor(1.1940725, shape=(), dtype=float32)
# The time of the epoch 59 is: 10.755379676818848 second
# 60/100: ==========> : loss = tf.Tensor(1.2681024, shape=(), dtype=float32)
# The time of the epoch 60 is: 10.805535793304443 second
# 61/100: ==========> : loss = tf.Tensor(1.3032955, shape=(), dtype=float32)
# The time of the epoch 61 is: 10.794970989227295 second
# 62/100: ==========> : loss = tf.Tensor(1.2714853, shape=(), dtype=float32)
# The time of the epoch 62 is: 10.795937776565552 second
# 63/100: ==========> : loss = tf.Tensor(1.2852101, shape=(), dtype=float32)
# The time of the epoch 63 is: 10.78981900215149 second
# 64/100: ==========> : loss = tf.Tensor(1.2214284, shape=(), dtype=float32)
# The time of the epoch 64 is: 10.792737007141113 second
# 65/100: ==========> : loss = tf.Tensor(1.2018611, shape=(), dtype=float32)
# The time of the epoch 65 is: 20.46406364440918 second
# 66/100: ==========> : loss = tf.Tensor(1.2135137, shape=(), dtype=float32)
# The time of the epoch 66 is: 10.793338298797607 second
# 67/100: ==========> : loss = tf.Tensor(1.2971098, shape=(), dtype=float32)
# The time of the epoch 67 is: 20.463958263397217 second
# 68/100: ==========> : loss = tf.Tensor(1.2482994, shape=(), dtype=float32)
# The time of the epoch 68 is: 10.886562824249268 second
# 69/100: ==========> : loss = tf.Tensor(1.2657372, shape=(), dtype=float32)
# The time of the epoch 69 is: 10.931104183197021 second
# 70/100: ==========> : loss = tf.Tensor(1.2071977, shape=(), dtype=float32)
# The time of the epoch 70 is: 10.911954879760742 second
# 71/100: ==========> : loss = tf.Tensor(1.1895212, shape=(), dtype=float32)
# The time of the epoch 71 is: 10.799797534942627 second
# 72/100: ==========> : loss = tf.Tensor(1.1632559, shape=(), dtype=float32)
# The time of the epoch 72 is: 10.774164915084839 second
# 73/100: ==========> : loss = tf.Tensor(1.2018025, shape=(), dtype=float32)
# The time of the epoch 73 is: 10.74976110458374 second
# 74/100: ==========> : loss = tf.Tensor(1.1854827, shape=(), dtype=float32)
# The time of the epoch 74 is: 10.734375 second
# 75/100: ==========> : loss = tf.Tensor(1.2019837, shape=(), dtype=float32)
# The time of the epoch 75 is: 10.757680177688599 second
# 76/100: ==========> : loss = tf.Tensor(1.1823292, shape=(), dtype=float32)
# The time of the epoch 76 is: 10.778550386428833 second
# 77/100: ==========> : loss = tf.Tensor(1.105913, shape=(), dtype=float32)
# The time of the epoch 77 is: 10.789588451385498 second
# 78/100: ==========> : loss = tf.Tensor(1.1297424, shape=(), dtype=float32)
# The time of the epoch 78 is: 10.809815406799316 second
# 79/100: ==========> : loss = tf.Tensor(1.1012484, shape=(), dtype=float32)
# The time of the epoch 79 is: 10.780814170837402 second
# 80/100: ==========> : loss = tf.Tensor(1.0930368, shape=(), dtype=float32)
# The time of the epoch 80 is: 20.464488744735718 second
# 81/100: ==========> : loss = tf.Tensor(1.1934026, shape=(), dtype=float32)
# The time of the epoch 81 is: 10.77702784538269 second
# 82/100: ==========> : loss = tf.Tensor(1.2863189, shape=(), dtype=float32)
# The time of the epoch 82 is: 10.831008672714233 second
# 83/100: ==========> : loss = tf.Tensor(1.270172, shape=(), dtype=float32)
# The time of the epoch 83 is: 10.903749942779541 second
# 84/100: ==========> : loss = tf.Tensor(1.1602372, shape=(), dtype=float32)
# The time of the epoch 84 is: 10.842854261398315 second
# 85/100: ==========> : loss = tf.Tensor(1.1314181, shape=(), dtype=float32)
# The time of the epoch 85 is: 10.810096979141235 second
# 86/100: ==========> : loss = tf.Tensor(1.1670616, shape=(), dtype=float32)
# The time of the epoch 86 is: 10.753360033035278 second
# 87/100: ==========> : loss = tf.Tensor(1.1796448, shape=(), dtype=float32)
# The time of the epoch 87 is: 10.727246522903442 second
# 88/100: ==========> : loss = tf.Tensor(1.2509133, shape=(), dtype=float32)
# The time of the epoch 88 is: 10.749458074569702 second
# 89/100: ==========> : loss = tf.Tensor(1.2161254, shape=(), dtype=float32)
# The time of the epoch 89 is: 10.758162260055542 second
# 90/100: ==========> : loss = tf.Tensor(1.2945876, shape=(), dtype=float32)
# The time of the epoch 90 is: 10.77386736869812 second
# 91/100: ==========> : loss = tf.Tensor(1.3412178, shape=(), dtype=float32)
# The time of the epoch 91 is: 10.778536558151245 second
# 92/100: ==========> : loss = tf.Tensor(1.2387054, shape=(), dtype=float32)
# The time of the epoch 92 is: 10.77878475189209 second
# 93/100: ==========> : loss = tf.Tensor(1.3503916, shape=(), dtype=float32)
# The time of the epoch 93 is: 10.783120155334473 second
# 94/100: ==========> : loss = tf.Tensor(1.3936709, shape=(), dtype=float32)
# The time of the epoch 94 is: 10.78933572769165 second
# 95/100: ==========> : loss = tf.Tensor(1.2559565, shape=(), dtype=float32)
# The time of the epoch 95 is: 10.80453372001648 second
# 96/100: ==========> : loss = tf.Tensor(1.2395638, shape=(), dtype=float32)
# The time of the epoch 96 is: 20.472721576690674 second
# 97/100: ==========> : loss = tf.Tensor(1.2285571, shape=(), dtype=float32)
# The time of the epoch 97 is: 10.766307830810547 second
# 98/100: ==========> : loss = tf.Tensor(1.3023275, shape=(), dtype=float32)
# The time of the epoch 98 is: 10.834292650222778 second
# 99/100: ==========> : loss = tf.Tensor(1.2609911, shape=(), dtype=float32)
# The time of the epoch 99 is: 10.902249813079834 second
# 100/100: ==========> : loss = tf.Tensor(1.254369, shape=(), dtype=float32)
# The time of the epoch 100 is: 10.847200155258179 second

# %%
plt.figure(figsize=(24, 10))
plt.title('Visualization of the generator learning process', fontsize=16)
plt.plot(np.arange(1, EPOCHS + 1), gen_history)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.xlim(1, EPOCHS)
plt.grid()
plt.legend(fontsize=16)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
n = 4
total = 2 * n + 1
cnter = 0
plt.figure(figsize=(28, 8))

num = 1
for i in range(-n, n + 1):
    for j in range(-n, n + 1):
        ax = plt.subplot(7, 11, num)
        num += 1
        img = generator.predict(np.expand_dims([0.5 * i / n, 0.5 * j / n], axis=0))
        plt.imshow(img[0, :, :, 0], cmap='gray')
        plt.axis('off')
        if num == 78:
            break
plt.show()
# Out:
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
